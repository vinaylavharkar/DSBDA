# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/covid_19_clean_complete_2022.csv')
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.tail()
# Out:
#        Province/State        Country/Region        Lat        Long  \
# 214889            NaN    West Bank and Gaza  31.952200   35.233200
# 214890            NaN  Winter Olympics 2022  39.904200  116.407400
# 214891            NaN                 Yemen  15.552727   48.516388
# 214892            NaN                Zambia -13.133897   27.849332
# 214893            NaN              Zimbabwe -19.015438   29.154857
#
#               Date  Confirmed  Deaths  Recovered  Active  \
# 214889  2022-03-04     649971    5557          0  644414
# 214890  2022-03-04        530       0          0     530
# 214891  2022-03-04      11774    2135          0    9639
# 214892  2022-03-04     313613    3958          0  309655
# 214893  2022-03-04     238739    5397          0  233342
#
#                    WHO Region
# 214889  Eastern Mediterranean
# 214890                    NaN
# 214891  Eastern Mediterranean
# 214892                 Africa
# 214893                 Africa

# %%
df.shape
# Out:
# (214894, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214894 entries, 0 to 214893
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  65705 non-null   object
#  1   Country/Region  214894 non-null  object
#  2   Lat             213348 non-null  float64
#  3   Long            213348 non-null  float64
#  4   Date            214894 non-null  object
#  5   Confirmed       214894 non-null  int64
#  6   Deaths          214894 non-null  int64
#  7   Recovered       214894 non-null  int64
#  8   Active          214894 non-null  int64
#  9   WHO Region      212575 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 16.4+ MB

# %%
df.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object

# %%
df.isnull()
# Out:
#         Province/State  Country/Region    Lat   Long   Date  Confirmed  \
# 0                 True           False  False  False  False      False
# 1                 True           False  False  False  False      False
# 2                 True           False  False  False  False      False
# 3                 True           False  False  False  False      False
# 4                 True           False  False  False  False      False
# ...                ...             ...    ...    ...    ...        ...
# 214889            True           False  False  False  False      False
# 214890            True           False  False  False  False      False
# 214891            True           False  False  False  False      False
# 214892            True           False  False  False  False      False
# 214893            True           False  False  False  False      False
#
#         Deaths  Recovered  Active  WHO Region
# 0        False      False   False       False
# ...

# %%
df.isnull().sum()
# Out:
# Province/State    149189
# Country/Region         0
# Lat                 1546
# Long                1546
# Date                   0
# Confirmed              0
# Deaths                 0
# Recovered              0
# Active                 0
# WHO Region          2319
# dtype: int64

# %%
df.replace(np.nan,df['Lat'].mean(), inplace=True)

# %%
df.replace(np.nan, df['Long'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# WHO Region        0
# dtype: int64

# %%
df.iloc[5]
# Out:
# Province/State     20.528131
# Country/Region    Antarctica
# Lat                 -71.9499
# Long                  23.347
# Date              2020-01-22
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# WHO Region         20.528131
# Name: 5, dtype: object

# %%
df.iloc[:5,:3]
# Out:
#   Province/State Country/Region       Lat
# 0      20.528131    Afghanistan  33.93911
# 1      20.528131        Albania  41.15330
# 2      20.528131        Algeria  28.03390
# 3      20.528131        Andorra  42.50630
# 4      20.528131         Angola -11.20270

# %%
df['Lat'] = df['Lat'].astype('int')
print(df['Lat'])
# Out:
# 0         33
# 1         41
# 2         28
# 3         42
# 4        -11
#           ..
# 214889    31
# 214890    39
# 214891    15
# 214892   -13
# 214893   -19
# Name: Lat, Length: 214894, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

data = df['Long']

label_encoder = LabelEncoder()

encoded_data = label_encoder.fit_transform(data)
print(df.head())
# Out:
#   Province/State Country/Region  Lat       Long        Date  Confirmed  \
# 0      20.528131    Afghanistan   33  67.709953  2020-01-22          0
# 1      20.528131        Albania   41  20.168300  2020-01-22          0
# 2      20.528131        Algeria   28   1.659600  2020-01-22          0
# 3      20.528131        Andorra   42   1.521800  2020-01-22          0
# 4      20.528131         Angola  -11  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
from sklearn.preprocessing import LabelEncoder

# Extract the first letter of each country name
df['Country Group'] = df['Country/Region'].str[0]

# Apply label encoding to the country groups
label_encoder = LabelEncoder()
df['Country Group Encoded'] = label_encoder.fit_transform(df['Country Group'])

# Display the result
print(df[['Country/Region', 'Country Group', 'Country Group Encoded']].sample(n=10))
# Out:
#          Country/Region Country Group  Country Group Encoded
# 148959  Solomon Islands             S                     18
# 125082   United Kingdom             U                     20
# 34420         Singapore             S                     18
# 159554   United Kingdom             U                     20
# 89337            Cyprus             C                      2
# 135690            Benin             B                      1
# 32944             Haiti             H                      7
# 183958           Norway             N                     13
# 123902      Netherlands             N                     13
# 42859            Canada             C                      2
